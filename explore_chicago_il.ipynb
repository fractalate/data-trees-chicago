# %% [markdown]
# # Urban DataMart Exploration for Chicago, IL

# %%
import numpy as np
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import pandas as pd
import pyproj

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
# For transforming lon/lat coordinates to x/y coordinate in feet suitable for Illinois
# https://en.wikipedia.org/wiki/EPSG_Geodetic_Parameter_Dataset
# EPSG:4326 - https://epsg.io/4326
# EPSG:26971 - https://epsg.io/26971
transformer_ll_to_xy = pyproj.Transformer.from_crs('EPSG:4326', 'EPSG:26971', always_xy=True)

CHICAGO_LON = -87.623177
CHICAGO_LAT = 41.881832
CHICAGO_X, CHICAGO_Y = transformer_ll_to_xy.transform(CHICAGO_LON, CHICAGO_LAT)

GARY_LON = -87.356934
GARY_LAT = 41.595161
GARY_X, GARY_Y = transformer_ll_to_xy.transform(GARY_LON, GARY_LAT)

NAPERVILLE_LON = -88.186111
NAPERVILLE_LAT = 41.748489
NAPERVILLE_X, NAPERVILLE_Y = transformer_ll_to_xy.transform(NAPERVILLE_LON, NAPERVILLE_LAT)

WAUKEGEN_LON = -87.872139
WAUKEGEN_LAT = 42.365627
WAUKEGEN_X, WAUKEGEN_Y = transformer_ll_to_xy.transform(WAUKEGEN_LON, WAUKEGEN_LAT)

# %% [markdown]
# ## Load Source Tables

# %% [markdown]
# The `ID_PLOT` table contains information about the locations or plots where trees are surveyed. This data include approximate locations.

# %%
df_id_plot = pd.read_csv('./data/Urban DataMart/Chicago_IL_CSV/ID_PLOT.csv')
print('Records:', len(df_id_plot))
print('Columns:', list(df_id_plot.columns))
df_id_plot[:1]
# Out:
# Records: 583
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'INTENSITY', 'MEAS_YEAR', 'MEAS_MONTH', 'MEAS_DAY', 'KINDCD', 'PLOT_STATUS_CD', 'PLOT_NONSAMPLE_REASN_CD', 'SAMPLE_METHOD_CD', 'MANUAL_NATIONAL', 'MANUAL_REGIONAL', 'LAT', 'LON', 'ROAD_DIST_CD', 'WATER_CD', 'SUBP_EXAMINE_CD', 'CN', 'PREV_PLT_CN']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  INTENSITY  \
# 0  1469468          1       55       5        59         22287          5
#
#    MEAS_YEAR  MEAS_MONTH  MEAS_DAY  KINDCD  PLOT_STATUS_CD  \
# 0       2017           6        29       1               2
#
#    PLOT_NONSAMPLE_REASN_CD  SAMPLE_METHOD_CD MANUAL_NATIONAL MANUAL_REGIONAL  \
# 0                      NaN               NaN             7.1             7.1
#
#          LAT        LON  ROAD_DIST_CD  WATER_CD  SUBP_EXAMINE_CD      CN  \
# 0  42.550977 -88.259189           NaN       NaN                1  923674
#
#    PREV_PLT_CN
# 0          NaN

# %% [markdown]
# The `ID_TREE` table contains information about individual trees.

# %%
df_id_tree = pd.read_csv('./data/Urban DataMart/Chicago_IL_CSV/ID_TREE.csv')
print('Records:', len(df_id_tree))
print('Columns:', list(df_id_tree.columns))
df_id_tree[:1]
# Out:
# Records: 2138
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'SUBP', 'CONDID', 'TREE', 'STEM', 'MOTHER_TREE', 'OFFSET_POINT', 'DIST', 'AZIMUTH', 'STATUSCD', 'TREECLCD', 'SPCD', 'SPGRPCD', 'STANDING_DEAD_CD', 'UTILCLCD', 'MORTYR', 'DIA', 'DIACHECK', 'DIAHTCD', 'LTDMP', 'TOTAL_LENGTH', 'ACTUAL_LENGTH', 'HTCD', 'ABNORMAL_STEM_TERMINATION', 'RECONCILECD', 'BOLE_STUMP_REMOVED', 'FIELD_PREV_DIA', 'FIELD_PREV_STATUS_CD', 'FIELD_PREV_NBR_STEMS', 'CROWN_CLASS_CD', 'COMP_CROWN_RATIO', 'DMG_ROOT_STEM_GIRDLING', 'DMG_TRUNK_BARK_INCLUSION', 'DMG_TOPPING_PRUNING', 'DMG_EXCESS_MULCH', 'DMG_SIDEWALK_ROOT_CONFLICT', 'DMG_OVERHEAD_WIRES', 'DMG_IMPROPER_PLANTING', 'DAMAGE_AGENT_1', 'DAMAGE_AGENT_2', 'DAMAGE_AGENT_3', 'NBR_STEMS', 'CULL_FLD', 'ROUGHCULL', 'CAUSE_OF_DEATH', 'DECAYCD', 'MORTALITY_CD', 'TREECLCD_NRS', 'TREECLCD_SRS', 'TREECLCD_PNWRS', 'TREECLCD_RMRS', 'TREE_GRADE', 'TREE_SITE_INDEX', 'BASAL_AREA', 'TPA_UNADJ', 'CARBON_AG', 'CARBON_BG', 'DRYBIO_AG', 'DRYBIO_BG', 'DRYBIO_BOLE', 'DRYBIO_BOLE_BARK', 'DRYBIO_BRANCH', 'DRYBIO_FOLIAGE', 'DRYBIO_SAWLOG', 'DRYBIO_SAWLOG_BARK', 'DRYBIO_STEM', 'DRYBIO_STEM_BARK', 'DRYBIO_STUMP', 'DRYBIO_STUMP_BARK', 'VOLBFGRS', 'VOLBFNET', 'VOLBSGRS', 'VOLBSNET', 'VOLCFGRS', 'VOLCFGRS_BARK', 'VOLCFGRS_STUMP', 'VOLCFGRS_STUMP_BARK', 'VOLCFGRS_TOP', 'VOLCFGRS_TOP_BARK', 'VOLCFNET', 'VOLCFNET_BARK', 'VOLCFSND', 'VOLCFSND_BARK', 'VOLCFSND_STUMP', 'VOLCFSND_STUMP_BARK', 'VOLCFSND_TOP', 'VOLCFSND_TOP_BARK', 'VOLCSGRS', 'VOLCSGRS_BARK', 'VOLCSNET', 'VOLCSNET_BARK', 'VOLCSSND', 'VOLCSSND_BARK', 'VOLTSGRS', 'VOLTSGRS_BARK', 'VOLTSSND', 'VOLTSSND_BARK', 'CN', 'PLT_CN', 'SBP_CN', 'CND_CN', 'MTRE_CN', 'PREV_PLT_CN', 'PREV_TRE_CN']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  SUBP  CONDID  \
# 0  1915119          4       18       4       127         20096     1       1
#
#    TREE  STEM  MOTHER_TREE  OFFSET_POINT  DIST  AZIMUTH  STATUSCD  TREECLCD  \
# 0    20    20          NaN           NaN   NaN      NaN         1       2.0
#
#    SPCD  SPGRPCD  STANDING_DEAD_CD  UTILCLCD  MORTYR  DIA  DIACHECK  DIAHTCD  \
# 0   972       41               NaN       NaN     NaN  7.7       0.0        1
#
#    LTDMP  TOTAL_LENGTH  ACTUAL_LENGTH  HTCD  ABNORMAL_STEM_TERMINATION  \
# 0    NaN          55.0            NaN   1.0                        NaN
#
#    RECONCILECD  BOLE_STUMP_REMOVED  FIELD_PREV_DIA  FIELD_PREV_STATUS_CD  \
# 0          NaN                 NaN             NaN                   NaN
#
#    FIELD_PREV_NBR_STEMS  CROWN_CLASS_CD  COMP_CROWN_RATIO  \
# 0                   NaN             4.0              29.0
#
#    DMG_ROOT_STEM_GIRDLING  DMG_TRUNK_BARK_INCLUSION  DMG_TOPPING_PRUNING  \
# 0                     0.0                       0.0                  0.0
#
#    DMG_EXCESS_MULCH  DMG_SIDEWALK_ROOT_CONFLICT  DMG_OVERHEAD_WIRES  \
# 0               0.0                         0.0                 0.0
#
#    DMG_IMPROPER_PLANTING  DAMAGE_AGENT_1  DAMAGE_AGENT_2  DAMAGE_AGENT_3  \
# 0                    0.0             0.0             NaN             NaN
#
#    NBR_STEMS  CULL_FLD  ROUGHCULL  CAUSE_OF_DEATH  DECAYCD  MORTALITY_CD  \
# 0        NaN       0.0        NaN             NaN      NaN           NaN
#
#    TREECLCD_NRS  TREECLCD_SRS  TREECLCD_PNWRS  TREECLCD_RMRS  TREE_GRADE  \
# 0           2.0           NaN             NaN            NaN         NaN
#
#    TREE_SITE_INDEX  BASAL_AREA  TPA_UNADJ   CARBON_AG  CARBON_BG   DRYBIO_AG  \
# 0             73.0    0.323368   6.018046  139.025654  25.581387  291.458395
#
#    DRYBIO_BG  DRYBIO_BOLE  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0  53.629742   170.099862         22.310469      63.234442        6.246563
#
#    DRYBIO_SAWLOG  DRYBIO_SAWLOG_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0            NaN                 NaN   201.760803          26.46315
#
#    DRYBIO_STUMP  DRYBIO_STUMP_BARK  VOLBFGRS  VOLBFNET  VOLBSGRS  VOLBSNET  \
# 0     14.343245           1.881274       NaN       NaN       NaN       NaN
#
#    VOLCFGRS  VOLCFGRS_BARK  VOLCFGRS_STUMP  VOLCFGRS_STUMP_BARK  VOLCFGRS_TOP  \
# 0   5.86057       0.973352        0.494178             0.082076      0.596659
#
#    VOLCFGRS_TOP_BARK  VOLCFNET  VOLCFNET_BARK  VOLCFSND  VOLCFSND_BARK  \
# 0           0.099096  5.743359       0.963619  5.801965       0.973352
#
#    VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  VOLCFSND_TOP  VOLCFSND_TOP_BARK  \
# 0        0.489236             0.082076      0.590692           0.099096
#
#    VOLCSGRS  VOLCSGRS_BARK  VOLCSNET  VOLCSNET_BARK  VOLCSSND  VOLCSSND_BARK  \
# 0       NaN            NaN       NaN            NaN       NaN            NaN
#
#    VOLTSGRS  VOLTSGRS_BARK  VOLTSSND  VOLTSSND_BARK               CN  \
# 0  6.951407       1.154524  6.881893       1.154524  942084333290487
#
#             PLT_CN           SBP_CN           CND_CN          MTRE_CN  \
# 0  352769580489998  942084252290487  942084249290487  942084292290487
#
#    PREV_PLT_CN  PREV_TRE_CN
# 0          NaN          NaN

# %% [markdown]
# The `REF_PLANT_DICTIONARY` table contains information about plant species as defined by the Natural Resources Conservation Service (NRCS) for the PLANTS database (see also https://plants.usda.gov).

# %%
df_ref_plant_dictionary = pd.read_csv('./data/Urban DataMart/Chicago_IL_CSV/REF_PLANT_DICTIONARY.csv', low_memory=False)
print('Records:', len(df_ref_plant_dictionary))
print('Columns:', list(df_ref_plant_dictionary.columns))
df_ref_plant_dictionary[:1]
# Out:
# Records: 81489
# Columns: ['CN', 'SYMBOL_TYPE', 'SYMBOL', 'SCIENTIFIC_NAME', 'NEW_SYMBOL', 'NEW_SCIENTIFIC_NAME', 'COMMON_NAME', 'CATEGORY', 'FAMILY', 'GROWTH_HABIT', 'DURATION', 'US_NATIVITY', 'STATE_DISTRIBUTION', 'STATE_AND_PROVINCE', 'SCIENTIFIC_NAME_W_AUTHOR', 'GENERA_BINOMIAL_AUTHOR', 'TRINOMIAL_AUTHOR', 'QUADRINOMIAL_AUTHOR', 'XGENUS', 'GENUS', 'XSPECIES', 'SPECIES', 'SSP', 'XSUBSPECIES', 'SUBSPECIES', 'VAR', 'XVARIETY', 'VARIETY', 'SUBVAR', 'SUBVARIETY', 'F', 'FORMA', 'NOTES', 'CREATED_BY', 'CREATED_DATE', 'CREATED_IN_INSTANCE', 'MODIFIED_BY', 'MODIFIED_DATE', 'MODIFIED_IN_INSTANCE']
#                 CN SYMBOL_TYPE SYMBOL        SCIENTIFIC_NAME NEW_SYMBOL  \
# 0  503517201126144         Old  NOFR3  Nothoscordum fragrans       NOBO
#
#        NEW_SCIENTIFIC_NAME COMMON_NAME CATEGORY FAMILY GROWTH_HABIT DURATION  \
# 0  Nothoscordum borbonicum         NaN      NaN    NaN          NaN      NaN
#
#   US_NATIVITY STATE_DISTRIBUTION STATE_AND_PROVINCE  \
# 0         NaN                NaN                NaN
#
#                         SCIENTIFIC_NAME_W_AUTHOR   GENERA_BINOMIAL_AUTHOR  \
# 0  Nothoscordum fragrans auct. non (Vent.) Kunth  auct. non (Vent.) Kunth
#
#   TRINOMIAL_AUTHOR QUADRINOMIAL_AUTHOR XGENUS         GENUS XSPECIES  \
# 0              NaN                 NaN    NaN  Nothoscordum      NaN
#
#     SPECIES  SSP XSUBSPECIES SUBSPECIES  VAR XVARIETY VARIETY SUBVAR  \
# 0  fragrans  NaN         NaN        NaN  NaN      NaN     NaN    NaN
#
#   SUBVARIETY    F FORMA NOTES   CREATED_BY         CREATED_DATE  \
# 0        NaN  NaN   NaN   NaN  ERICHDODSON  2018-02-09 12:59:36
#
#    CREATED_IN_INSTANCE  MODIFIED_BY        MODIFIED_DATE  MODIFIED_IN_INSTANCE
# 0               126144  ERICHDODSON  2018-02-12 11:12:26              126144.0

# %% [markdown]
# The `REF_SPECIES` table contains a reference of species codes in the `SPCD` column.

# %%
df_ref_species = pd.read_csv('./data/Urban DataMart/Chicago_IL_CSV/REF_SPECIES.csv')
print('Records:', len(df_ref_species))
print('Columns:', list(df_ref_species.columns))
df_ref_species[:1]
# Out:
# Records: 2697
# Columns: ['SPCD', 'COMMON_NAME', 'SHARED_COMMON_NAME_IND', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES', 'SCIENTIFIC_NAME', 'SPECIES_SYMBOL', 'E_SPGRPCD', 'W_SPGRPCD', 'C_SPGRPCD', 'P_SPGRPCD', 'MAJOR_SPGRPCD', 'STOCKING_SPGRPCD', 'FOREST_TYPE_SPGRPCD', 'JENKINS_SPGRPCD', 'JENKINS_SAPLING_ADJUSTMENT', 'SITETREE', 'SFTWD_HRDWD', 'WOODLAND', 'WOOD_SPGR_GREENVOL_DRYWT', 'WOOD_SPGR_GREENVOL_DRYWT_CIT', 'BARK_SPGR_GREENVOL_DRYWT', 'BARK_SPGR_GREENVOL_DRYWT_CIT', 'MC_PCT_GREEN_WOOD', 'MC_PCT_GREEN_WOOD_CIT', 'MC_PCT_GREEN_BARK', 'MC_PCT_GREEN_BARK_CIT', 'BARK_VOL_PCT', 'BARK_VOL_PCT_CIT', 'CWD_DECAY_RATIO1', 'CWD_DECAY_RATIO2', 'CWD_DECAY_RATIO3', 'CWD_DECAY_RATIO4', 'CWD_DECAY_RATIO5', 'DWM_CARBON_RATIO', 'CARBON_RATIO_LIVE', 'DRYWT_TO_GREENWT_CONVERSION', 'CREATED_DATE', 'MODIFIED_DATE']
#    SPCD       COMMON_NAME SHARED_COMMON_NAME_IND   GENUS   SPECIES VARIETY  \
# 0  6012  spineless wattle                      N  Acacia  muricata     NaN
#
#   SUBSPECIES  SCIENTIFIC_NAME SPECIES_SYMBOL  E_SPGRPCD  W_SPGRPCD  C_SPGRPCD  \
# 0        NaN  Acacia muricata           ACMU       54.0       54.0       54.0
#
#    P_SPGRPCD  MAJOR_SPGRPCD  STOCKING_SPGRPCD  FOREST_TYPE_SPGRPCD  \
# 0        NaN              3              37.0                227.0
#
#    JENKINS_SPGRPCD  JENKINS_SAPLING_ADJUSTMENT SITETREE SFTWD_HRDWD WOODLAND  \
# 0                8                     0.84031      NaN           H        N
#
#    WOOD_SPGR_GREENVOL_DRYWT  WOOD_SPGR_GREENVOL_DRYWT_CIT  \
# 0                      0.52                          26.0
#
#    BARK_SPGR_GREENVOL_DRYWT  BARK_SPGR_GREENVOL_DRYWT_CIT  MC_PCT_GREEN_WOOD  \
# 0                      0.53                          26.0              75.13
#
#    MC_PCT_GREEN_WOOD_CIT  MC_PCT_GREEN_BARK  MC_PCT_GREEN_BARK_CIT  \
# 0                   26.0              80.49                   26.0
#
#    BARK_VOL_PCT  BARK_VOL_PCT_CIT  CWD_DECAY_RATIO1  CWD_DECAY_RATIO2  \
# 0         15.16              26.0               1.0              0.78
#
#    CWD_DECAY_RATIO3  CWD_DECAY_RATIO4  CWD_DECAY_RATIO5  DWM_CARBON_RATIO  \
# 0              0.45              0.42              0.42             0.491
#
#    CARBON_RATIO_LIVE  DRYWT_TO_GREENWT_CONVERSION         CREATED_DATE  \
# 0              0.475                     1.758474  2021-09-03 22:38:53
#
#   MODIFIED_DATE
# 0           NaN

# %% [markdown]
# The `REF_TREE_STATUS` table stores reference data for the `STATUSCD` attribute in the `ID_MOTHER_TREE` and `ID_TREE` tables. Code for this attribute indicates the status of a tree at the time of measurement.

# %%
TREE_STATUS_LIVE = 1
TREE_STATUS_DEAD = 2

df_ref_tree_status = pd.read_csv('./data/Urban DataMart/Chicago_IL_CSV/REF_TREE_STATUS.csv')
print('Records:', len(df_ref_tree_status))
print('Columns:', list(df_ref_tree_status.columns))
df_ref_tree_status
# Out:
# Records: 5
# Columns: ['VALUE', 'ABBR', 'MEANING', 'RETIRED']
#    VALUE            ABBR  \
# 0      0       No Status
# 1      1            Live
# 2      2            Dead
# 3      3  Cut & Utilized
# 4      4         Removed
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                               MEANING  \
# 0                                                                                                                                                                                                                                                                                                                                                                         No status – tree is not presently in the sample (remeasurement plots only).
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                           Live tree
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                           Dead tree
# 3  Cut & Utilized – Collected on remeasurement trees only. A tree that occupied a forested condition in the previous inventory only. A tree that has been cut and removed by direct human activity related to harvesting, silviculture or land clearing. The tree is assumed to have been utilized for a commercial purposes, such as timber, chips, or firewood, and noncommercial purposes such as domestic firewood, landscaping, and fence posts.
# 4                                                                                                                                                                    Removed – Collected on remeasurement trees only. A tree that has been removed by direct human activity but not likely utilized for a commercial product, such as timber, chips, or firewood, and noncommercial purposes such as domestic firewood, landscaping, and fence posts.
#
#   RETIRED
# 0       N
# 1       N
# 2       N
# 3       N
# 4       N

# %% [markdown]
# The `wcvp_taxon` table contains taxonomic information about vascular plants. Of interest to us are its trees.

# %%
df_wcvp_taxon = pd.read_csv('./data/wcvp_dwca/wcvp_taxon.csv', sep='|')
print('Records:', len(df_wcvp_taxon))
print('Columns:', list(df_wcvp_taxon.columns))
df_wcvp_taxon[:1]
# Out:
# Records: 1440076
# Columns: ['taxonid', 'family', 'genus', 'specificepithet', 'infraspecificepithet', 'scientfiicname', 'scientfiicnameauthorship', 'taxonrank', 'taxonomicstatus', 'acceptednameusageid', 'parentnameusageid', 'originalnameusageid', 'namepublishedin', 'nomenclaturalstatus', 'taxonremarks', 'scientificnameid', 'dynamicproperties', 'references']
#    taxonid         family          genus specificepithet infraspecificepithet  \
# 0  3152367  Polypodiaceae  Elaphoglossum        pygmaeum                  NaN
#
#            scientfiicname scientfiicnameauthorship taxonrank taxonomicstatus  \
# 0  Elaphoglossum pygmaeum           (Mett.) Christ   Species        Accepted
#
#    acceptednameusageid  parentnameusageid  originalnameusageid  \
# 0            3152367.0          3189746.0            3180440.0
#
#                      namepublishedin nomenclaturalstatus         taxonremarks  \
# 0  Monogr. Elaphoglossum: 111 (1899)                 NaN  Colombia to Ecuador
#
#   scientificnameid  \
# 0  ipni:17105050-1
#
#                                                                                                                 dynamicproperties  \
# 0  {"powoid":"17105050-1","lifeform":"epiphyte","climate":"wet tropical","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
#
#                                                               references
# 0  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:17105050-1

# %% [markdown]
# The `wcvp_distribution` table contains information about the establishment means of plants in various locales.

# %%
df_wcvp_distribution = pd.read_csv('./data/wcvp_dwca/wcvp_distribution.csv', sep='|')
print('Records:', len(df_wcvp_distribution))
print('Columns:', list(df_wcvp_distribution.columns))
df_wcvp_distribution[:1]
# Out:
# Records: 1983653
# Columns: ['coreid', 'locality', 'establishmentmeans', 'locationid', 'occurrencestatus', 'threatstatus']
#    coreid             locality establishmentmeans locationid occurrencestatus  \
# 0       1  Argentina Northeast                NaN   TDWG:AGE              NaN
#
#   threatstatus
# 0          NaN

# %% [markdown]
# ## Data Filtering Methodology
#
# <div style="display:none;">
# ```mermaid
# graph
#     df_id_tree --> df_id_tree_with_species
#     df_ref_species -->|merge on SPCD, brings<br/>genus, species, variety,<br/>subspecies, common name| df_id_tree_with_species
#     df_id_tree_with_species -->|filter to just trees that<br/>are alive and are<br/>individual trees| df_trees
#     df_ref_plant_dictionary -->|filter to just current, species<br/>level records for Illinois| df_ref_plant_dictionary_illinois
#     df_ref_plant_dictionary_illinois -->|determine nativity| df_ref_plant_dictionary_illinois_nativity
#     df_trees --> df_trees_illinois
#     df_ref_plant_dictionary_illinois_nativity -->|merge on genus, species,<br/>variety, and subspecies| df_illinois_nativity
#     df_id_plot -->|integrate lat/lon<br/>and x/y| df_trees_chicago
#     df_trees_illinois -->|manual inspection of<br/>nativity information for<br/>Chicago| df_trees_chicago
#     df_illinois_nativity --> df_trees_illinois
#     df_wcvp_taxon -->|filter to just accepted records<br/>and are species| df_wcvp_taxon_species
#     df_wcvp_distribution -->|filter to just illinois| df_wcvp_distribution_illinois
#     df_wcvp_taxon_species --> df_wcvp_taxon_species_illinois
#     df_wcvp_distribution_illinois -->|merge on genus, species bring in<br/>establishmentmeans| df_wcvp_taxon_species_illinois
#     df_wcvp_taxon_species_illinois -->|determine nativity| df_wcvp_taxon_species_illinois_nativity
#     df_wcvp_taxon_species_illinois_nativity --> df_illinois_nativity
#     style df_id_tree fill:LightBlue,stroke:SteelBlue
#     style df_id_plot fill:LightBlue,stroke:SteelBlue
#     style df_ref_species fill:LightBlue,stroke:SteelBlue
#     style df_ref_plant_dictionary fill:LightBlue,stroke:SteelBlue
#     style df_wcvp_taxon fill:LightBlue,stroke:SteelBlue
#     style df_wcvp_distribution fill:LightBlue,stroke:SteelBlue
#     style df_trees_chicago fill:PaleGreen,stroke:SeaGreen
# ```
# </div>
#
# ![Filtering Methodology Diagram](./filtering_methodology_diagram.png)

# %% [markdown]
# ## Data Filtering

# %%
df_id_tree_with_species = pd.merge(
    df_id_tree,
    df_ref_species[['SPCD', 'COMMON_NAME', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES']],
    on='SPCD',
    how='left',
)
print('Records:', len(df_id_tree_with_species))
print('Columns:', list(df_id_tree_with_species.columns))
df_id_tree_with_species[:1]
# Out:
# Records: 2138
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'SUBP', 'CONDID', 'TREE', 'STEM', 'MOTHER_TREE', 'OFFSET_POINT', 'DIST', 'AZIMUTH', 'STATUSCD', 'TREECLCD', 'SPCD', 'SPGRPCD', 'STANDING_DEAD_CD', 'UTILCLCD', 'MORTYR', 'DIA', 'DIACHECK', 'DIAHTCD', 'LTDMP', 'TOTAL_LENGTH', 'ACTUAL_LENGTH', 'HTCD', 'ABNORMAL_STEM_TERMINATION', 'RECONCILECD', 'BOLE_STUMP_REMOVED', 'FIELD_PREV_DIA', 'FIELD_PREV_STATUS_CD', 'FIELD_PREV_NBR_STEMS', 'CROWN_CLASS_CD', 'COMP_CROWN_RATIO', 'DMG_ROOT_STEM_GIRDLING', 'DMG_TRUNK_BARK_INCLUSION', 'DMG_TOPPING_PRUNING', 'DMG_EXCESS_MULCH', 'DMG_SIDEWALK_ROOT_CONFLICT', 'DMG_OVERHEAD_WIRES', 'DMG_IMPROPER_PLANTING', 'DAMAGE_AGENT_1', 'DAMAGE_AGENT_2', 'DAMAGE_AGENT_3', 'NBR_STEMS', 'CULL_FLD', 'ROUGHCULL', 'CAUSE_OF_DEATH', 'DECAYCD', 'MORTALITY_CD', 'TREECLCD_NRS', 'TREECLCD_SRS', 'TREECLCD_PNWRS', 'TREECLCD_RMRS', 'TREE_GRADE', 'TREE_SITE_INDEX', 'BASAL_AREA', 'TPA_UNADJ', 'CARBON_AG', 'CARBON_BG', 'DRYBIO_AG', 'DRYBIO_BG', 'DRYBIO_BOLE', 'DRYBIO_BOLE_BARK', 'DRYBIO_BRANCH', 'DRYBIO_FOLIAGE', 'DRYBIO_SAWLOG', 'DRYBIO_SAWLOG_BARK', 'DRYBIO_STEM', 'DRYBIO_STEM_BARK', 'DRYBIO_STUMP', 'DRYBIO_STUMP_BARK', 'VOLBFGRS', 'VOLBFNET', 'VOLBSGRS', 'VOLBSNET', 'VOLCFGRS', 'VOLCFGRS_BARK', 'VOLCFGRS_STUMP', 'VOLCFGRS_STUMP_BARK', 'VOLCFGRS_TOP', 'VOLCFGRS_TOP_BARK', 'VOLCFNET', 'VOLCFNET_BARK', 'VOLCFSND', 'VOLCFSND_BARK', 'VOLCFSND_STUMP', 'VOLCFSND_STUMP_BARK', 'VOLCFSND_TOP', 'VOLCFSND_TOP_BARK', 'VOLCSGRS', 'VOLCSGRS_BARK', 'VOLCSNET', 'VOLCSNET_BARK', 'VOLCSSND', 'VOLCSSND_BARK', 'VOLTSGRS', 'VOLTSGRS_BARK', 'VOLTSSND', 'VOLTSSND_BARK', 'CN', 'PLT_CN', 'SBP_CN', 'CND_CN', 'MTRE_CN', 'PREV_PLT_CN', 'PREV_TRE_CN', 'COMMON_NAME', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  SUBP  CONDID  \
# 0  1915119          4       18       4       127         20096     1       1
#
#    TREE  STEM  MOTHER_TREE  OFFSET_POINT  DIST  AZIMUTH  STATUSCD  TREECLCD  \
# 0    20    20          NaN           NaN   NaN      NaN         1       2.0
#
#    SPCD  SPGRPCD  STANDING_DEAD_CD  UTILCLCD  MORTYR  DIA  DIACHECK  DIAHTCD  \
# 0   972       41               NaN       NaN     NaN  7.7       0.0        1
#
#    LTDMP  TOTAL_LENGTH  ACTUAL_LENGTH  HTCD  ABNORMAL_STEM_TERMINATION  \
# 0    NaN          55.0            NaN   1.0                        NaN
#
#    RECONCILECD  BOLE_STUMP_REMOVED  FIELD_PREV_DIA  FIELD_PREV_STATUS_CD  \
# 0          NaN                 NaN             NaN                   NaN
#
#    FIELD_PREV_NBR_STEMS  CROWN_CLASS_CD  COMP_CROWN_RATIO  \
# 0                   NaN             4.0              29.0
#
#    DMG_ROOT_STEM_GIRDLING  DMG_TRUNK_BARK_INCLUSION  DMG_TOPPING_PRUNING  \
# 0                     0.0                       0.0                  0.0
#
#    DMG_EXCESS_MULCH  DMG_SIDEWALK_ROOT_CONFLICT  DMG_OVERHEAD_WIRES  \
# 0               0.0                         0.0                 0.0
#
#    DMG_IMPROPER_PLANTING  DAMAGE_AGENT_1  DAMAGE_AGENT_2  DAMAGE_AGENT_3  \
# 0                    0.0             0.0             NaN             NaN
#
#    NBR_STEMS  CULL_FLD  ROUGHCULL  CAUSE_OF_DEATH  DECAYCD  MORTALITY_CD  \
# 0        NaN       0.0        NaN             NaN      NaN           NaN
#
#    TREECLCD_NRS  TREECLCD_SRS  TREECLCD_PNWRS  TREECLCD_RMRS  TREE_GRADE  \
# 0           2.0           NaN             NaN            NaN         NaN
#
#    TREE_SITE_INDEX  BASAL_AREA  TPA_UNADJ   CARBON_AG  CARBON_BG   DRYBIO_AG  \
# 0             73.0    0.323368   6.018046  139.025654  25.581387  291.458395
#
#    DRYBIO_BG  DRYBIO_BOLE  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0  53.629742   170.099862         22.310469      63.234442        6.246563
#
#    DRYBIO_SAWLOG  DRYBIO_SAWLOG_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0            NaN                 NaN   201.760803          26.46315
#
#    DRYBIO_STUMP  DRYBIO_STUMP_BARK  VOLBFGRS  VOLBFNET  VOLBSGRS  VOLBSNET  \
# 0     14.343245           1.881274       NaN       NaN       NaN       NaN
#
#    VOLCFGRS  VOLCFGRS_BARK  VOLCFGRS_STUMP  VOLCFGRS_STUMP_BARK  VOLCFGRS_TOP  \
# 0   5.86057       0.973352        0.494178             0.082076      0.596659
#
#    VOLCFGRS_TOP_BARK  VOLCFNET  VOLCFNET_BARK  VOLCFSND  VOLCFSND_BARK  \
# 0           0.099096  5.743359       0.963619  5.801965       0.973352
#
#    VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  VOLCFSND_TOP  VOLCFSND_TOP_BARK  \
# 0        0.489236             0.082076      0.590692           0.099096
#
#    VOLCSGRS  VOLCSGRS_BARK  VOLCSNET  VOLCSNET_BARK  VOLCSSND  VOLCSSND_BARK  \
# 0       NaN            NaN       NaN            NaN       NaN            NaN
#
#    VOLTSGRS  VOLTSGRS_BARK  VOLTSSND  VOLTSSND_BARK               CN  \
# 0  6.951407       1.154524  6.881893       1.154524  942084333290487
#
#             PLT_CN           SBP_CN           CND_CN          MTRE_CN  \
# 0  352769580489998  942084252290487  942084249290487  942084292290487
#
#    PREV_PLT_CN  PREV_TRE_CN   COMMON_NAME  GENUS    SPECIES VARIETY SUBSPECIES
# 0          NaN          NaN  American elm  Ulmus  americana     NaN        NaN

# %%
df_trees = df_id_tree_with_species[
    (df_id_tree_with_species['STATUSCD'] == TREE_STATUS_LIVE)  # Living.
    &(df_id_tree_with_species['TREE'] == df_id_tree_with_species['STEM'])  # Individual trees.
]
print('Records:', len(df_trees))
print('Columns:', list(df_trees.columns))
df_trees[:1]
# Out:
# Records: 1740
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'SUBP', 'CONDID', 'TREE', 'STEM', 'MOTHER_TREE', 'OFFSET_POINT', 'DIST', 'AZIMUTH', 'STATUSCD', 'TREECLCD', 'SPCD', 'SPGRPCD', 'STANDING_DEAD_CD', 'UTILCLCD', 'MORTYR', 'DIA', 'DIACHECK', 'DIAHTCD', 'LTDMP', 'TOTAL_LENGTH', 'ACTUAL_LENGTH', 'HTCD', 'ABNORMAL_STEM_TERMINATION', 'RECONCILECD', 'BOLE_STUMP_REMOVED', 'FIELD_PREV_DIA', 'FIELD_PREV_STATUS_CD', 'FIELD_PREV_NBR_STEMS', 'CROWN_CLASS_CD', 'COMP_CROWN_RATIO', 'DMG_ROOT_STEM_GIRDLING', 'DMG_TRUNK_BARK_INCLUSION', 'DMG_TOPPING_PRUNING', 'DMG_EXCESS_MULCH', 'DMG_SIDEWALK_ROOT_CONFLICT', 'DMG_OVERHEAD_WIRES', 'DMG_IMPROPER_PLANTING', 'DAMAGE_AGENT_1', 'DAMAGE_AGENT_2', 'DAMAGE_AGENT_3', 'NBR_STEMS', 'CULL_FLD', 'ROUGHCULL', 'CAUSE_OF_DEATH', 'DECAYCD', 'MORTALITY_CD', 'TREECLCD_NRS', 'TREECLCD_SRS', 'TREECLCD_PNWRS', 'TREECLCD_RMRS', 'TREE_GRADE', 'TREE_SITE_INDEX', 'BASAL_AREA', 'TPA_UNADJ', 'CARBON_AG', 'CARBON_BG', 'DRYBIO_AG', 'DRYBIO_BG', 'DRYBIO_BOLE', 'DRYBIO_BOLE_BARK', 'DRYBIO_BRANCH', 'DRYBIO_FOLIAGE', 'DRYBIO_SAWLOG', 'DRYBIO_SAWLOG_BARK', 'DRYBIO_STEM', 'DRYBIO_STEM_BARK', 'DRYBIO_STUMP', 'DRYBIO_STUMP_BARK', 'VOLBFGRS', 'VOLBFNET', 'VOLBSGRS', 'VOLBSNET', 'VOLCFGRS', 'VOLCFGRS_BARK', 'VOLCFGRS_STUMP', 'VOLCFGRS_STUMP_BARK', 'VOLCFGRS_TOP', 'VOLCFGRS_TOP_BARK', 'VOLCFNET', 'VOLCFNET_BARK', 'VOLCFSND', 'VOLCFSND_BARK', 'VOLCFSND_STUMP', 'VOLCFSND_STUMP_BARK', 'VOLCFSND_TOP', 'VOLCFSND_TOP_BARK', 'VOLCSGRS', 'VOLCSGRS_BARK', 'VOLCSNET', 'VOLCSNET_BARK', 'VOLCSSND', 'VOLCSSND_BARK', 'VOLTSGRS', 'VOLTSGRS_BARK', 'VOLTSSND', 'VOLTSSND_BARK', 'CN', 'PLT_CN', 'SBP_CN', 'CND_CN', 'MTRE_CN', 'PREV_PLT_CN', 'PREV_TRE_CN', 'COMMON_NAME', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  SUBP  CONDID  \
# 0  1915119          4       18       4       127         20096     1       1
#
#    TREE  STEM  MOTHER_TREE  OFFSET_POINT  DIST  AZIMUTH  STATUSCD  TREECLCD  \
# 0    20    20          NaN           NaN   NaN      NaN         1       2.0
#
#    SPCD  SPGRPCD  STANDING_DEAD_CD  UTILCLCD  MORTYR  DIA  DIACHECK  DIAHTCD  \
# 0   972       41               NaN       NaN     NaN  7.7       0.0        1
#
#    LTDMP  TOTAL_LENGTH  ACTUAL_LENGTH  HTCD  ABNORMAL_STEM_TERMINATION  \
# 0    NaN          55.0            NaN   1.0                        NaN
#
#    RECONCILECD  BOLE_STUMP_REMOVED  FIELD_PREV_DIA  FIELD_PREV_STATUS_CD  \
# 0          NaN                 NaN             NaN                   NaN
#
#    FIELD_PREV_NBR_STEMS  CROWN_CLASS_CD  COMP_CROWN_RATIO  \
# 0                   NaN             4.0              29.0
#
#    DMG_ROOT_STEM_GIRDLING  DMG_TRUNK_BARK_INCLUSION  DMG_TOPPING_PRUNING  \
# 0                     0.0                       0.0                  0.0
#
#    DMG_EXCESS_MULCH  DMG_SIDEWALK_ROOT_CONFLICT  DMG_OVERHEAD_WIRES  \
# 0               0.0                         0.0                 0.0
#
#    DMG_IMPROPER_PLANTING  DAMAGE_AGENT_1  DAMAGE_AGENT_2  DAMAGE_AGENT_3  \
# 0                    0.0             0.0             NaN             NaN
#
#    NBR_STEMS  CULL_FLD  ROUGHCULL  CAUSE_OF_DEATH  DECAYCD  MORTALITY_CD  \
# 0        NaN       0.0        NaN             NaN      NaN           NaN
#
#    TREECLCD_NRS  TREECLCD_SRS  TREECLCD_PNWRS  TREECLCD_RMRS  TREE_GRADE  \
# 0           2.0           NaN             NaN            NaN         NaN
#
#    TREE_SITE_INDEX  BASAL_AREA  TPA_UNADJ   CARBON_AG  CARBON_BG   DRYBIO_AG  \
# 0             73.0    0.323368   6.018046  139.025654  25.581387  291.458395
#
#    DRYBIO_BG  DRYBIO_BOLE  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0  53.629742   170.099862         22.310469      63.234442        6.246563
#
#    DRYBIO_SAWLOG  DRYBIO_SAWLOG_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0            NaN                 NaN   201.760803          26.46315
#
#    DRYBIO_STUMP  DRYBIO_STUMP_BARK  VOLBFGRS  VOLBFNET  VOLBSGRS  VOLBSNET  \
# 0     14.343245           1.881274       NaN       NaN       NaN       NaN
#
#    VOLCFGRS  VOLCFGRS_BARK  VOLCFGRS_STUMP  VOLCFGRS_STUMP_BARK  VOLCFGRS_TOP  \
# 0   5.86057       0.973352        0.494178             0.082076      0.596659
#
#    VOLCFGRS_TOP_BARK  VOLCFNET  VOLCFNET_BARK  VOLCFSND  VOLCFSND_BARK  \
# 0           0.099096  5.743359       0.963619  5.801965       0.973352
#
#    VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  VOLCFSND_TOP  VOLCFSND_TOP_BARK  \
# 0        0.489236             0.082076      0.590692           0.099096
#
#    VOLCSGRS  VOLCSGRS_BARK  VOLCSNET  VOLCSNET_BARK  VOLCSSND  VOLCSSND_BARK  \
# 0       NaN            NaN       NaN            NaN       NaN            NaN
#
#    VOLTSGRS  VOLTSGRS_BARK  VOLTSSND  VOLTSSND_BARK               CN  \
# 0  6.951407       1.154524  6.881893       1.154524  942084333290487
#
#             PLT_CN           SBP_CN           CND_CN          MTRE_CN  \
# 0  352769580489998  942084252290487  942084249290487  942084292290487
#
#    PREV_PLT_CN  PREV_TRE_CN   COMMON_NAME  GENUS    SPECIES VARIETY SUBSPECIES
# 0          NaN          NaN  American elm  Ulmus  americana     NaN        NaN

# %%
df_ref_plant_dictionary_illinois = df_ref_plant_dictionary[
    (df_ref_plant_dictionary['SYMBOL_TYPE'] == 'Species')  # Identifies a species and is not old.
    &(df_ref_plant_dictionary['STATE_DISTRIBUTION'].str.contains('IL', na=False, regex=False))  # Found in Illinois.
]
print('Records:', len(df_ref_plant_dictionary_illinois))
print('Columns:', list(df_ref_plant_dictionary_illinois.columns))
df_ref_plant_dictionary_illinois[:1]
# Out:
# Records: 4170
# Columns: ['CN', 'SYMBOL_TYPE', 'SYMBOL', 'SCIENTIFIC_NAME', 'NEW_SYMBOL', 'NEW_SCIENTIFIC_NAME', 'COMMON_NAME', 'CATEGORY', 'FAMILY', 'GROWTH_HABIT', 'DURATION', 'US_NATIVITY', 'STATE_DISTRIBUTION', 'STATE_AND_PROVINCE', 'SCIENTIFIC_NAME_W_AUTHOR', 'GENERA_BINOMIAL_AUTHOR', 'TRINOMIAL_AUTHOR', 'QUADRINOMIAL_AUTHOR', 'XGENUS', 'GENUS', 'XSPECIES', 'SPECIES', 'SSP', 'XSUBSPECIES', 'SUBSPECIES', 'VAR', 'XVARIETY', 'VARIETY', 'SUBVAR', 'SUBVARIETY', 'F', 'FORMA', 'NOTES', 'CREATED_BY', 'CREATED_DATE', 'CREATED_IN_INSTANCE', 'MODIFIED_BY', 'MODIFIED_DATE', 'MODIFIED_IN_INSTANCE']
#                  CN SYMBOL_TYPE SYMBOL SCIENTIFIC_NAME NEW_SYMBOL  \
# 17  503517222126144     Species   NULU    Nuphar lutea        NaN
#
#    NEW_SCIENTIFIC_NAME       COMMON_NAME CATEGORY        FAMILY GROWTH_HABIT  \
# 17                 NaN  yellow pond-lily    Dicot  Nymphaeaceae    Forb/herb
#
#      DURATION              US_NATIVITY  \
# 17  Perennial  L48(N)AK(N)CAN(N)SPM(N)
#
#                                                                                                                                                                                         STATE_DISTRIBUTION  \
# 17  AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
#
#                                                                                                                                                                                                                                                                    STATE_AND_PROVINCE  \
# 17  CAN(AB, BC, LB, MB, NB, NF, NS, NT, NU, ON, PE, QC, SK, YT), FRA(SB), USA(AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY)
#
#    SCIENTIFIC_NAME_W_AUTHOR GENERA_BINOMIAL_AUTHOR TRINOMIAL_AUTHOR  \
# 17    Nuphar lutea (L.) Sm.               (L.) Sm.              NaN
#
#    QUADRINOMIAL_AUTHOR XGENUS   GENUS XSPECIES SPECIES  SSP XSUBSPECIES  \
# 17                 NaN    NaN  Nuphar      NaN   lutea  NaN         NaN
#
#    SUBSPECIES  VAR XVARIETY VARIETY SUBVAR SUBVARIETY    F FORMA NOTES  \
# 17        NaN  NaN      NaN     NaN    NaN        NaN  NaN   NaN   NaN
#
#      CREATED_BY         CREATED_DATE  CREATED_IN_INSTANCE  MODIFIED_BY  \
# 17  ERICHDODSON  2018-02-09 12:59:36               126144  ERICHDODSON
#
#           MODIFIED_DATE  MODIFIED_IN_INSTANCE
# 17  2018-02-12 11:12:26              126144.0

# %%
df_ref_plant_dictionary_illinois_nativity = df_ref_plant_dictionary_illinois.copy()
df_ref_plant_dictionary_illinois_nativity['NATIVITY'] = (
    (
        (df_ref_plant_dictionary_illinois['US_NATIVITY'].str.contains('L48(N', na=False, regex=False))  # Native or pobably native in lower 48.
        &(~df_ref_plant_dictionary_illinois['US_NATIVITY'].str.contains('IL(I', na=False, regex=False))  # Not invasive in Illinois.
    )
    |(df_ref_plant_dictionary_illinois['US_NATIVITY'].str.contains('IL(N', na=False, regex=False))  # Native or probably native in Illinois.
).map({True: 'native', False: 'non-native'})
df_ref_plant_dictionary_illinois_nativity['NATIVITY'] = df_ref_plant_dictionary_illinois_nativity['NATIVITY'].fillna('non-native')
print('Records:', len(df_ref_plant_dictionary_illinois_nativity))
print('Columns:', list(df_ref_plant_dictionary_illinois_nativity.columns))
df_ref_plant_dictionary_illinois_nativity[:1]
# Out:
# Records: 4170
# Columns: ['CN', 'SYMBOL_TYPE', 'SYMBOL', 'SCIENTIFIC_NAME', 'NEW_SYMBOL', 'NEW_SCIENTIFIC_NAME', 'COMMON_NAME', 'CATEGORY', 'FAMILY', 'GROWTH_HABIT', 'DURATION', 'US_NATIVITY', 'STATE_DISTRIBUTION', 'STATE_AND_PROVINCE', 'SCIENTIFIC_NAME_W_AUTHOR', 'GENERA_BINOMIAL_AUTHOR', 'TRINOMIAL_AUTHOR', 'QUADRINOMIAL_AUTHOR', 'XGENUS', 'GENUS', 'XSPECIES', 'SPECIES', 'SSP', 'XSUBSPECIES', 'SUBSPECIES', 'VAR', 'XVARIETY', 'VARIETY', 'SUBVAR', 'SUBVARIETY', 'F', 'FORMA', 'NOTES', 'CREATED_BY', 'CREATED_DATE', 'CREATED_IN_INSTANCE', 'MODIFIED_BY', 'MODIFIED_DATE', 'MODIFIED_IN_INSTANCE', 'NATIVITY']
#                  CN SYMBOL_TYPE SYMBOL SCIENTIFIC_NAME NEW_SYMBOL  \
# 17  503517222126144     Species   NULU    Nuphar lutea        NaN
#
#    NEW_SCIENTIFIC_NAME       COMMON_NAME CATEGORY        FAMILY GROWTH_HABIT  \
# 17                 NaN  yellow pond-lily    Dicot  Nymphaeaceae    Forb/herb
#
#      DURATION              US_NATIVITY  \
# 17  Perennial  L48(N)AK(N)CAN(N)SPM(N)
#
#                                                                                                                                                                                         STATE_DISTRIBUTION  \
# 17  AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY
#
#                                                                                                                                                                                                                                                                    STATE_AND_PROVINCE  \
# 17  CAN(AB, BC, LB, MB, NB, NF, NS, NT, NU, ON, PE, QC, SK, YT), FRA(SB), USA(AK, AL, AR, AZ, CA, CO, CT, DC, DE, FL, GA, IA, ID, IL, IN, KS, KY, LA, MA, MD, ME, MI, MN, MO, MS, MT, NC, ND, NE, NH, NJ, NM, NV, NY, OH, OK, OR, PA, RI, SC, SD, TN, TX, UT, VA, VT, WA, WI, WV, WY)
#
#    SCIENTIFIC_NAME_W_AUTHOR GENERA_BINOMIAL_AUTHOR TRINOMIAL_AUTHOR  \
# 17    Nuphar lutea (L.) Sm.               (L.) Sm.              NaN
#
#    QUADRINOMIAL_AUTHOR XGENUS   GENUS XSPECIES SPECIES  SSP XSUBSPECIES  \
# 17                 NaN    NaN  Nuphar      NaN   lutea  NaN         NaN
#
#    SUBSPECIES  VAR XVARIETY VARIETY SUBVAR SUBVARIETY    F FORMA NOTES  \
# 17        NaN  NaN      NaN     NaN    NaN        NaN  NaN   NaN   NaN
#
#      CREATED_BY         CREATED_DATE  CREATED_IN_INSTANCE  MODIFIED_BY  \
# 17  ERICHDODSON  2018-02-09 12:59:36               126144  ERICHDODSON
#
#           MODIFIED_DATE  MODIFIED_IN_INSTANCE NATIVITY
# 17  2018-02-12 11:12:26              126144.0   native

# %%
df_wcvp_taxon_species = df_wcvp_taxon[
    (df_wcvp_taxon['taxonomicstatus'] == 'Accepted')
    &(df_wcvp_taxon['taxonrank'] == 'Species')
]
print('Records:', len(df_wcvp_taxon_species))
print('Columns:', list(df_wcvp_taxon_species.columns))
df_wcvp_taxon_species[:1]
# Out:
# Records: 362754
# Columns: ['taxonid', 'family', 'genus', 'specificepithet', 'infraspecificepithet', 'scientfiicname', 'scientfiicnameauthorship', 'taxonrank', 'taxonomicstatus', 'acceptednameusageid', 'parentnameusageid', 'originalnameusageid', 'namepublishedin', 'nomenclaturalstatus', 'taxonremarks', 'scientificnameid', 'dynamicproperties', 'references']
#    taxonid         family          genus specificepithet infraspecificepithet  \
# 0  3152367  Polypodiaceae  Elaphoglossum        pygmaeum                  NaN
#
#            scientfiicname scientfiicnameauthorship taxonrank taxonomicstatus  \
# 0  Elaphoglossum pygmaeum           (Mett.) Christ   Species        Accepted
#
#    acceptednameusageid  parentnameusageid  originalnameusageid  \
# 0            3152367.0          3189746.0            3180440.0
#
#                      namepublishedin nomenclaturalstatus         taxonremarks  \
# 0  Monogr. Elaphoglossum: 111 (1899)                 NaN  Colombia to Ecuador
#
#   scientificnameid  \
# 0  ipni:17105050-1
#
#                                                                                                                 dynamicproperties  \
# 0  {"powoid":"17105050-1","lifeform":"epiphyte","climate":"wet tropical","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
#
#                                                               references
# 0  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:17105050-1

# %%
df_wcvp_distribution_illinois = df_wcvp_distribution[
    df_wcvp_distribution['locality'] == 'Illinois'
]
print('Records:', len(df_wcvp_distribution_illinois))
print('Columns:', list(df_wcvp_distribution_illinois.columns))
df_wcvp_distribution_illinois[:1]
# Out:
# Records: 5216
# Columns: ['coreid', 'locality', 'establishmentmeans', 'locationid', 'occurrencestatus', 'threatstatus']
#      coreid  locality establishmentmeans locationid occurrencestatus  \
# 155     126  Illinois                NaN   TDWG:ILL              NaN
#
#     threatstatus
# 155          NaN

# %%
df_wcvp_taxon_species_illinois = df_wcvp_taxon_species.merge(
    df_wcvp_distribution_illinois[['coreid', 'establishmentmeans']],
    left_on=['taxonid'],
    right_on=['coreid'],
)
df_wcvp_taxon_species_illinois = df_wcvp_taxon_species_illinois.drop('coreid', axis=1)
print('Records:', len(df_wcvp_taxon_species_illinois))
print('Columns:', list(df_wcvp_taxon_species_illinois.columns))
df_wcvp_taxon_species_illinois[:1]
# Out:
# Records: 3350
# Columns: ['taxonid', 'family', 'genus', 'specificepithet', 'infraspecificepithet', 'scientfiicname', 'scientfiicnameauthorship', 'taxonrank', 'taxonomicstatus', 'acceptednameusageid', 'parentnameusageid', 'originalnameusageid', 'namepublishedin', 'nomenclaturalstatus', 'taxonremarks', 'scientificnameid', 'dynamicproperties', 'references', 'establishmentmeans']
#    taxonid    family     genus specificepithet infraspecificepithet  \
# 0  2639317  Apiaceae  Angelica        venenosa                  NaN
#
#       scientfiicname scientfiicnameauthorship taxonrank taxonomicstatus  \
# 0  Angelica venenosa       (Greenway) Fernald   Species        Accepted
#
#    acceptednameusageid  parentnameusageid  originalnameusageid  \
# 0            2639317.0          2638971.0            2720773.0
#
#           namepublishedin nomenclaturalstatus     taxonremarks  \
# 0  Rhodora 45: 301 (1943)                 NaN  NC. & E. U.S.A.
#
#   scientificnameid  \
# 0     ipni:13671-2
#
#                                                                                                            dynamicproperties  \
# 0  {"powoid":"13671-2","lifeform":"perennial","climate":"temperate","homotypicsynonym":"","hybridformula":"","reviewed":"N"}
#
#                                                            references  \
# 0  https://powo.science.kew.org/taxon/urn:lsid:ipni.org:names:13671-2
#
#   establishmentmeans
# 0                NaN

# %%
df_wcvp_taxon_species_illinois_nativity = df_wcvp_taxon_species_illinois

df_wcvp_taxon_species_illinois_nativity['nativity'] = df_wcvp_taxon_species_illinois_nativity['establishmentmeans'].map({ 'introduced': 'non-native' })
df_wcvp_taxon_species_illinois_nativity['nativity'] = df_wcvp_taxon_species_illinois_nativity['nativity'].fillna('native')
df_wcvp_taxon_species_illinois_nativity = df_wcvp_taxon_species_illinois_nativity.drop('establishmentmeans', axis=1)
print('Records:', len(df_wcvp_taxon_species_illinois_nativity))
print('Columns:', list(df_wcvp_taxon_species_illinois_nativity.columns))
df_wcvp_taxon_species_illinois_nativity[['nativity']].value_counts(dropna=False)
# Out:
# Records: 3350
# Columns: ['taxonid', 'family', 'genus', 'specificepithet', 'infraspecificepithet', 'scientfiicname', 'scientfiicnameauthorship', 'taxonrank', 'taxonomicstatus', 'acceptednameusageid', 'parentnameusageid', 'originalnameusageid', 'namepublishedin', 'nomenclaturalstatus', 'taxonremarks', 'scientificnameid', 'dynamicproperties', 'references', 'nativity']
# nativity
# native        2317
# non-native    1033
# Name: count, dtype: int64

# %%
# `NATIVITY` is from df_ref_plant_dictionary_illinois_nativity
# `nativity` is from df_wcvp_taxon_species_illinois_nativity
df_illinois_nativity = df_ref_plant_dictionary_illinois_nativity.merge(
    df_wcvp_taxon_species_illinois_nativity[['genus', 'specificepithet', 'nativity']],
    left_on=['GENUS', 'SPECIES'],
    right_on=['genus', 'specificepithet'],
)
df_illinois_nativity = df_illinois_nativity.drop('genus', axis=1)
df_illinois_nativity = df_illinois_nativity.drop('specificepithet', axis=1)
df_illinois_nativity = df_illinois_nativity.drop('NATIVITY', axis=1)
df_illinois_nativity = df_illinois_nativity.rename(columns={
    'nativity': 'NATIVITY',
})
print('Records:', len(df_illinois_nativity))
print('Columns:', list(df_illinois_nativity.columns))
df_illinois_nativity[:1]
# Out:
# Records: 3495
# Columns: ['CN', 'SYMBOL_TYPE', 'SYMBOL', 'SCIENTIFIC_NAME', 'NEW_SYMBOL', 'NEW_SCIENTIFIC_NAME', 'COMMON_NAME', 'CATEGORY', 'FAMILY', 'GROWTH_HABIT', 'DURATION', 'US_NATIVITY', 'STATE_DISTRIBUTION', 'STATE_AND_PROVINCE', 'SCIENTIFIC_NAME_W_AUTHOR', 'GENERA_BINOMIAL_AUTHOR', 'TRINOMIAL_AUTHOR', 'QUADRINOMIAL_AUTHOR', 'XGENUS', 'GENUS', 'XSPECIES', 'SPECIES', 'SSP', 'XSUBSPECIES', 'SUBSPECIES', 'VAR', 'XVARIETY', 'VARIETY', 'SUBVAR', 'SUBVARIETY', 'F', 'FORMA', 'NOTES', 'CREATED_BY', 'CREATED_DATE', 'CREATED_IN_INSTANCE', 'MODIFIED_BY', 'MODIFIED_DATE', 'MODIFIED_IN_INSTANCE', 'NATIVITY']
#                 CN SYMBOL_TYPE SYMBOL      SCIENTIFIC_NAME NEW_SYMBOL  \
# 0  503517906126144     Species   OELI  Oenothera linifolia        NaN
#
#   NEW_SCIENTIFIC_NAME                  COMMON_NAME CATEGORY      FAMILY  \
# 0                 NaN  threadleaf evening primrose    Dicot  Onagraceae
#
#   GROWTH_HABIT DURATION US_NATIVITY  \
# 0    Forb/herb   Annual      L48(N)
#
#                                                STATE_DISTRIBUTION  \
# 0  AL, AR, FL, GA, IL, KS, KY, LA, MO, MS, NC, OK, SC, TN, TX, VA
#
#                                                     STATE_AND_PROVINCE  \
# 0  USA(AL, AR, FL, GA, IL, KS, KY, LA, MO, MS, NC, OK, SC, TN, TX, VA)
#
#     SCIENTIFIC_NAME_W_AUTHOR GENERA_BINOMIAL_AUTHOR TRINOMIAL_AUTHOR  \
# 0  Oenothera linifolia Nutt.                  Nutt.              NaN
#
#   QUADRINOMIAL_AUTHOR XGENUS      GENUS XSPECIES    SPECIES  SSP XSUBSPECIES  \
# 0                 NaN    NaN  Oenothera      NaN  linifolia  NaN         NaN
#
#   SUBSPECIES  VAR XVARIETY VARIETY SUBVAR SUBVARIETY    F FORMA NOTES  \
# 0        NaN  NaN      NaN     NaN    NaN        NaN  NaN   NaN   NaN
#
#     CREATED_BY         CREATED_DATE  CREATED_IN_INSTANCE  MODIFIED_BY  \
# 0  ERICHDODSON  2018-02-09 12:59:41               126144  ERICHDODSON
#
#          MODIFIED_DATE  MODIFIED_IN_INSTANCE NATIVITY
# 0  2018-02-12 11:12:25              126144.0   native

# %%
# TODO - build this next
df_trees_illinois = df_trees.merge(
    df_illinois_nativity[['GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES', 'NATIVITY']],
    on=['GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES'],
    how='left',
)
df_trees_illinois['NATIVITY'] = df_trees_illinois['NATIVITY'].fillna('non-native')
print('Records:', len(df_trees_illinois))
print('Columns:', list(df_trees_illinois.columns))
df_trees_illinois[:1]
# Out:
# Records: 1740
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'SUBP', 'CONDID', 'TREE', 'STEM', 'MOTHER_TREE', 'OFFSET_POINT', 'DIST', 'AZIMUTH', 'STATUSCD', 'TREECLCD', 'SPCD', 'SPGRPCD', 'STANDING_DEAD_CD', 'UTILCLCD', 'MORTYR', 'DIA', 'DIACHECK', 'DIAHTCD', 'LTDMP', 'TOTAL_LENGTH', 'ACTUAL_LENGTH', 'HTCD', 'ABNORMAL_STEM_TERMINATION', 'RECONCILECD', 'BOLE_STUMP_REMOVED', 'FIELD_PREV_DIA', 'FIELD_PREV_STATUS_CD', 'FIELD_PREV_NBR_STEMS', 'CROWN_CLASS_CD', 'COMP_CROWN_RATIO', 'DMG_ROOT_STEM_GIRDLING', 'DMG_TRUNK_BARK_INCLUSION', 'DMG_TOPPING_PRUNING', 'DMG_EXCESS_MULCH', 'DMG_SIDEWALK_ROOT_CONFLICT', 'DMG_OVERHEAD_WIRES', 'DMG_IMPROPER_PLANTING', 'DAMAGE_AGENT_1', 'DAMAGE_AGENT_2', 'DAMAGE_AGENT_3', 'NBR_STEMS', 'CULL_FLD', 'ROUGHCULL', 'CAUSE_OF_DEATH', 'DECAYCD', 'MORTALITY_CD', 'TREECLCD_NRS', 'TREECLCD_SRS', 'TREECLCD_PNWRS', 'TREECLCD_RMRS', 'TREE_GRADE', 'TREE_SITE_INDEX', 'BASAL_AREA', 'TPA_UNADJ', 'CARBON_AG', 'CARBON_BG', 'DRYBIO_AG', 'DRYBIO_BG', 'DRYBIO_BOLE', 'DRYBIO_BOLE_BARK', 'DRYBIO_BRANCH', 'DRYBIO_FOLIAGE', 'DRYBIO_SAWLOG', 'DRYBIO_SAWLOG_BARK', 'DRYBIO_STEM', 'DRYBIO_STEM_BARK', 'DRYBIO_STUMP', 'DRYBIO_STUMP_BARK', 'VOLBFGRS', 'VOLBFNET', 'VOLBSGRS', 'VOLBSNET', 'VOLCFGRS', 'VOLCFGRS_BARK', 'VOLCFGRS_STUMP', 'VOLCFGRS_STUMP_BARK', 'VOLCFGRS_TOP', 'VOLCFGRS_TOP_BARK', 'VOLCFNET', 'VOLCFNET_BARK', 'VOLCFSND', 'VOLCFSND_BARK', 'VOLCFSND_STUMP', 'VOLCFSND_STUMP_BARK', 'VOLCFSND_TOP', 'VOLCFSND_TOP_BARK', 'VOLCSGRS', 'VOLCSGRS_BARK', 'VOLCSNET', 'VOLCSNET_BARK', 'VOLCSSND', 'VOLCSSND_BARK', 'VOLTSGRS', 'VOLTSGRS_BARK', 'VOLTSSND', 'VOLTSSND_BARK', 'CN', 'PLT_CN', 'SBP_CN', 'CND_CN', 'MTRE_CN', 'PREV_PLT_CN', 'PREV_TRE_CN', 'COMMON_NAME', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES', 'NATIVITY']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  SUBP  CONDID  \
# 0  1915119          4       18       4       127         20096     1       1
#
#    TREE  STEM  MOTHER_TREE  OFFSET_POINT  DIST  AZIMUTH  STATUSCD  TREECLCD  \
# 0    20    20          NaN           NaN   NaN      NaN         1       2.0
#
#    SPCD  SPGRPCD  STANDING_DEAD_CD  UTILCLCD  MORTYR  DIA  DIACHECK  DIAHTCD  \
# 0   972       41               NaN       NaN     NaN  7.7       0.0        1
#
#    LTDMP  TOTAL_LENGTH  ACTUAL_LENGTH  HTCD  ABNORMAL_STEM_TERMINATION  \
# 0    NaN          55.0            NaN   1.0                        NaN
#
#    RECONCILECD  BOLE_STUMP_REMOVED  FIELD_PREV_DIA  FIELD_PREV_STATUS_CD  \
# 0          NaN                 NaN             NaN                   NaN
#
#    FIELD_PREV_NBR_STEMS  CROWN_CLASS_CD  COMP_CROWN_RATIO  \
# 0                   NaN             4.0              29.0
#
#    DMG_ROOT_STEM_GIRDLING  DMG_TRUNK_BARK_INCLUSION  DMG_TOPPING_PRUNING  \
# 0                     0.0                       0.0                  0.0
#
#    DMG_EXCESS_MULCH  DMG_SIDEWALK_ROOT_CONFLICT  DMG_OVERHEAD_WIRES  \
# 0               0.0                         0.0                 0.0
#
#    DMG_IMPROPER_PLANTING  DAMAGE_AGENT_1  DAMAGE_AGENT_2  DAMAGE_AGENT_3  \
# 0                    0.0             0.0             NaN             NaN
#
#    NBR_STEMS  CULL_FLD  ROUGHCULL  CAUSE_OF_DEATH  DECAYCD  MORTALITY_CD  \
# 0        NaN       0.0        NaN             NaN      NaN           NaN
#
#    TREECLCD_NRS  TREECLCD_SRS  TREECLCD_PNWRS  TREECLCD_RMRS  TREE_GRADE  \
# 0           2.0           NaN             NaN            NaN         NaN
#
#    TREE_SITE_INDEX  BASAL_AREA  TPA_UNADJ   CARBON_AG  CARBON_BG   DRYBIO_AG  \
# 0             73.0    0.323368   6.018046  139.025654  25.581387  291.458395
#
#    DRYBIO_BG  DRYBIO_BOLE  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0  53.629742   170.099862         22.310469      63.234442        6.246563
#
#    DRYBIO_SAWLOG  DRYBIO_SAWLOG_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0            NaN                 NaN   201.760803          26.46315
#
#    DRYBIO_STUMP  DRYBIO_STUMP_BARK  VOLBFGRS  VOLBFNET  VOLBSGRS  VOLBSNET  \
# 0     14.343245           1.881274       NaN       NaN       NaN       NaN
#
#    VOLCFGRS  VOLCFGRS_BARK  VOLCFGRS_STUMP  VOLCFGRS_STUMP_BARK  VOLCFGRS_TOP  \
# 0   5.86057       0.973352        0.494178             0.082076      0.596659
#
#    VOLCFGRS_TOP_BARK  VOLCFNET  VOLCFNET_BARK  VOLCFSND  VOLCFSND_BARK  \
# 0           0.099096  5.743359       0.963619  5.801965       0.973352
#
#    VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  VOLCFSND_TOP  VOLCFSND_TOP_BARK  \
# 0        0.489236             0.082076      0.590692           0.099096
#
#    VOLCSGRS  VOLCSGRS_BARK  VOLCSNET  VOLCSNET_BARK  VOLCSSND  VOLCSSND_BARK  \
# 0       NaN            NaN       NaN            NaN       NaN            NaN
#
#    VOLTSGRS  VOLTSGRS_BARK  VOLTSSND  VOLTSSND_BARK               CN  \
# 0  6.951407       1.154524  6.881893       1.154524  942084333290487
#
#             PLT_CN           SBP_CN           CND_CN          MTRE_CN  \
# 0  352769580489998  942084252290487  942084249290487  942084292290487
#
#    PREV_PLT_CN  PREV_TRE_CN   COMMON_NAME  GENUS    SPECIES VARIETY  \
# 0          NaN          NaN  American elm  Ulmus  americana     NaN
#
#   SUBSPECIES NATIVITY
# 0        NaN   native

# %%
df = df_id_plot[['PLOTID', 'VISIT_NBR']].groupby(['PLOTID']).max().merge(
    df_id_plot,
    on=['PLOTID', 'VISIT_NBR'],
    how='left',
)
df_trees_chicago = df_trees_illinois.merge(
    df[['PLOTID', 'LAT', 'LON']],
    on=['PLOTID'],
)
df_trees_chicago[['X', 'Y']] = df_trees_chicago.apply(lambda row: transformer_ll_to_xy.transform(row['LON'], row['LAT']), axis=1, result_type='expand')
print('Records:', len(df_trees_chicago))
print('Columns:', list(df_trees_chicago.columns))
df_trees_chicago[:1]
# Out:
# Records: 1740
# Columns: ['PLOTID', 'VISIT_NBR', 'STATECD', 'UNITCD', 'COUNTYCD', 'RETIRED_PLOT', 'SUBP', 'CONDID', 'TREE', 'STEM', 'MOTHER_TREE', 'OFFSET_POINT', 'DIST', 'AZIMUTH', 'STATUSCD', 'TREECLCD', 'SPCD', 'SPGRPCD', 'STANDING_DEAD_CD', 'UTILCLCD', 'MORTYR', 'DIA', 'DIACHECK', 'DIAHTCD', 'LTDMP', 'TOTAL_LENGTH', 'ACTUAL_LENGTH', 'HTCD', 'ABNORMAL_STEM_TERMINATION', 'RECONCILECD', 'BOLE_STUMP_REMOVED', 'FIELD_PREV_DIA', 'FIELD_PREV_STATUS_CD', 'FIELD_PREV_NBR_STEMS', 'CROWN_CLASS_CD', 'COMP_CROWN_RATIO', 'DMG_ROOT_STEM_GIRDLING', 'DMG_TRUNK_BARK_INCLUSION', 'DMG_TOPPING_PRUNING', 'DMG_EXCESS_MULCH', 'DMG_SIDEWALK_ROOT_CONFLICT', 'DMG_OVERHEAD_WIRES', 'DMG_IMPROPER_PLANTING', 'DAMAGE_AGENT_1', 'DAMAGE_AGENT_2', 'DAMAGE_AGENT_3', 'NBR_STEMS', 'CULL_FLD', 'ROUGHCULL', 'CAUSE_OF_DEATH', 'DECAYCD', 'MORTALITY_CD', 'TREECLCD_NRS', 'TREECLCD_SRS', 'TREECLCD_PNWRS', 'TREECLCD_RMRS', 'TREE_GRADE', 'TREE_SITE_INDEX', 'BASAL_AREA', 'TPA_UNADJ', 'CARBON_AG', 'CARBON_BG', 'DRYBIO_AG', 'DRYBIO_BG', 'DRYBIO_BOLE', 'DRYBIO_BOLE_BARK', 'DRYBIO_BRANCH', 'DRYBIO_FOLIAGE', 'DRYBIO_SAWLOG', 'DRYBIO_SAWLOG_BARK', 'DRYBIO_STEM', 'DRYBIO_STEM_BARK', 'DRYBIO_STUMP', 'DRYBIO_STUMP_BARK', 'VOLBFGRS', 'VOLBFNET', 'VOLBSGRS', 'VOLBSNET', 'VOLCFGRS', 'VOLCFGRS_BARK', 'VOLCFGRS_STUMP', 'VOLCFGRS_STUMP_BARK', 'VOLCFGRS_TOP', 'VOLCFGRS_TOP_BARK', 'VOLCFNET', 'VOLCFNET_BARK', 'VOLCFSND', 'VOLCFSND_BARK', 'VOLCFSND_STUMP', 'VOLCFSND_STUMP_BARK', 'VOLCFSND_TOP', 'VOLCFSND_TOP_BARK', 'VOLCSGRS', 'VOLCSGRS_BARK', 'VOLCSNET', 'VOLCSNET_BARK', 'VOLCSSND', 'VOLCSSND_BARK', 'VOLTSGRS', 'VOLTSGRS_BARK', 'VOLTSSND', 'VOLTSSND_BARK', 'CN', 'PLT_CN', 'SBP_CN', 'CND_CN', 'MTRE_CN', 'PREV_PLT_CN', 'PREV_TRE_CN', 'COMMON_NAME', 'GENUS', 'SPECIES', 'VARIETY', 'SUBSPECIES', 'NATIVITY', 'LAT', 'LON', 'X', 'Y']
#     PLOTID  VISIT_NBR  STATECD  UNITCD  COUNTYCD  RETIRED_PLOT  SUBP  CONDID  \
# 0  1915119          4       18       4       127         20096     1       1
#
#    TREE  STEM  MOTHER_TREE  OFFSET_POINT  DIST  AZIMUTH  STATUSCD  TREECLCD  \
# 0    20    20          NaN           NaN   NaN      NaN         1       2.0
#
#    SPCD  SPGRPCD  STANDING_DEAD_CD  UTILCLCD  MORTYR  DIA  DIACHECK  DIAHTCD  \
# 0   972       41               NaN       NaN     NaN  7.7       0.0        1
#
#    LTDMP  TOTAL_LENGTH  ACTUAL_LENGTH  HTCD  ABNORMAL_STEM_TERMINATION  \
# 0    NaN          55.0            NaN   1.0                        NaN
#
#    RECONCILECD  BOLE_STUMP_REMOVED  FIELD_PREV_DIA  FIELD_PREV_STATUS_CD  \
# 0          NaN                 NaN             NaN                   NaN
#
#    FIELD_PREV_NBR_STEMS  CROWN_CLASS_CD  COMP_CROWN_RATIO  \
# 0                   NaN             4.0              29.0
#
#    DMG_ROOT_STEM_GIRDLING  DMG_TRUNK_BARK_INCLUSION  DMG_TOPPING_PRUNING  \
# 0                     0.0                       0.0                  0.0
#
#    DMG_EXCESS_MULCH  DMG_SIDEWALK_ROOT_CONFLICT  DMG_OVERHEAD_WIRES  \
# 0               0.0                         0.0                 0.0
#
#    DMG_IMPROPER_PLANTING  DAMAGE_AGENT_1  DAMAGE_AGENT_2  DAMAGE_AGENT_3  \
# 0                    0.0             0.0             NaN             NaN
#
#    NBR_STEMS  CULL_FLD  ROUGHCULL  CAUSE_OF_DEATH  DECAYCD  MORTALITY_CD  \
# 0        NaN       0.0        NaN             NaN      NaN           NaN
#
#    TREECLCD_NRS  TREECLCD_SRS  TREECLCD_PNWRS  TREECLCD_RMRS  TREE_GRADE  \
# 0           2.0           NaN             NaN            NaN         NaN
#
#    TREE_SITE_INDEX  BASAL_AREA  TPA_UNADJ   CARBON_AG  CARBON_BG   DRYBIO_AG  \
# 0             73.0    0.323368   6.018046  139.025654  25.581387  291.458395
#
#    DRYBIO_BG  DRYBIO_BOLE  DRYBIO_BOLE_BARK  DRYBIO_BRANCH  DRYBIO_FOLIAGE  \
# 0  53.629742   170.099862         22.310469      63.234442        6.246563
#
#    DRYBIO_SAWLOG  DRYBIO_SAWLOG_BARK  DRYBIO_STEM  DRYBIO_STEM_BARK  \
# 0            NaN                 NaN   201.760803          26.46315
#
#    DRYBIO_STUMP  DRYBIO_STUMP_BARK  VOLBFGRS  VOLBFNET  VOLBSGRS  VOLBSNET  \
# 0     14.343245           1.881274       NaN       NaN       NaN       NaN
#
#    VOLCFGRS  VOLCFGRS_BARK  VOLCFGRS_STUMP  VOLCFGRS_STUMP_BARK  VOLCFGRS_TOP  \
# 0   5.86057       0.973352        0.494178             0.082076      0.596659
#
#    VOLCFGRS_TOP_BARK  VOLCFNET  VOLCFNET_BARK  VOLCFSND  VOLCFSND_BARK  \
# 0           0.099096  5.743359       0.963619  5.801965       0.973352
#
#    VOLCFSND_STUMP  VOLCFSND_STUMP_BARK  VOLCFSND_TOP  VOLCFSND_TOP_BARK  \
# 0        0.489236             0.082076      0.590692           0.099096
#
#    VOLCSGRS  VOLCSGRS_BARK  VOLCSNET  VOLCSNET_BARK  VOLCSSND  VOLCSSND_BARK  \
# 0       NaN            NaN       NaN            NaN       NaN            NaN
#
#    VOLTSGRS  VOLTSGRS_BARK  VOLTSSND  VOLTSSND_BARK               CN  \
# 0  6.951407       1.154524  6.881893       1.154524  942084333290487
#
#             PLT_CN           SBP_CN           CND_CN          MTRE_CN  \
# 0  352769580489998  942084252290487  942084249290487  942084292290487
#
#    PREV_PLT_CN  PREV_TRE_CN   COMMON_NAME  GENUS    SPECIES VARIETY  \
# 0          NaN          NaN  American elm  Ulmus  americana     NaN
#
#   SUBSPECIES NATIVITY        LAT       LON              X              Y
# 0        NaN   native  41.566341 -87.03682  408141.764618  544749.584961

# %% [markdown]
# ## Questions and Answers

# %% [markdown]
# ### Which tree species are are represented in the tree dataset for Chicago?

# %%
df_trees_chicago[['GENUS', 'SPECIES', 'COMMON_NAME', 'NATIVITY']].value_counts(dropna=False)
# Out:
# GENUS         SPECIES        COMMON_NAME               NATIVITY
# Rhamnus       cathartica     common buckthorn          non-native    207
# Acer          saccharinum    silver maple              native        153
# Morus         alba           white mulberry            non-native    119
# Populus       deltoides      eastern cottonwood        native        103
# Acer          negundo        boxelder                  native         87
# Prunus        serotina       black cherry              native         86
# Ulmus         americana      American elm              native         71
# Acer          platanoides    Norway maple              non-native     71
# Tilia         americana      American basswood         native         51
# Quercus       macrocarpa     bur oak                   native         45
# Gleditsia     triacanthos    honeylocust               native         44
# Quercus       velutina       black oak                 native         39
# Ulmus         pumila         Siberian elm              non-native     38
# Fraxinus      pennsylvanica  green ash                 native         38
# Celtis        occidentalis   hackberry                 native         33
# Juglans       nigra          black walnut              native         28
# Pinus         strobus        eastern white pine        native         26
# Robinia       pseudoacacia   black locust              non-native     24
# Sassafras     albidum        sassafras                 native         23
# Carya         ovata          shagbark hickory          native         21
# Picea         pungens        blue spruce               non-native     20
# Quercus       rubra          northern red oak          native         20
# Acer          rubrum         red maple                 native         19
# Quercus       alba           white oak                 native         19
# Carya         cordiformis    bitternut hickory         native         19
# Acer          saccharum      sugar maple               native         18
# Malus         spp.           apple spp.                non-native     16
# Salix         nigra          black willow              native         15
# Tilia         cordata        littleleaf linden         non-native     15
# Betula        nigra          river birch               native         15
# Crataegus     spp.           hawthorn spp.             non-native     13
# Fraxinus      americana      white ash                 native         13
# Ailanthus     altissima      ailanthus                 non-native     12
# Thuja         occidentalis   northern white-cedar      native         12
# Picea         abies          Norway spruce             non-native     12
# Juniperus     virginiana     eastern redcedar          native         12
# Pinus         sylvestris     Scotch pine               non-native     12
#               resinosa       red pine                  native         12
# Acer          x freemanii    Freeman maple             non-native     10
# Liriodendron  tulipifera     yellow-poplar             native          8
# Catalpa       speciosa       northern catalpa          native          8
# Amelanchier   spp.           serviceberry spp.         non-native      8
# Picea         glauca         white spruce              non-native      8
# Betula        papyrifera     paper birch               native          7
# Quercus       palustris      pin oak                   native          7
# Pyrus         calleryana     Callery pear              non-native      7
# Cercis        canadensis     eastern redbud            native          7
# Quercus       ellipsoidalis  northern pin oak          native          5
# Ulmus         rubra          slippery elm              native          5
# Prunus        persica        peach                     non-native      5
# Salix         spp.           willow spp.               non-native      4
# Malus         baccata        Siberian crab apple       non-native      4
# Populus       tremuloides    quaking aspen             native          4
# Acer          nigrum         black maple               native          4
#               ginnala        Amur maple                non-native      3
# Abies         balsamea       balsam fir                non-native      3
# Salix         x sepulcralis  weeping willow            non-native      3
# Taxodium      distichum      baldcypress               native          3
# Crataegus     crus-galli     cockspur hawthorn         native          2
# Pyrus         spp.           pear spp.                 non-native      2
# Juglans       cinerea        butternut                 native          2
# Ginkgo        biloba         ginkgo                    non-native      2
# Gymnocladus   dioicus        Kentucky coffeetree       native          2
# Platanus      hybrida        London planetree          non-native      2
# Aesculus      glabra         Ohio buckeye              native          2
# Abies         concolor       white fir                 non-native      2
# Quercus       bicolor        swamp white oak           native          2
# Magnolia      stellata       star magnolia             non-native      2
# Ostrya        virginiana     eastern hophornbeam       native          2
# Pseudotsuga   menziesii      Douglas-fir               non-native      2
# Platanus      occidentalis   American sycamore         native          2
# Acer          palmatum       Japanese maple            non-native      1
# Corylus       colurna        Turkish hazelnut          non-native      1
# Catalpa       spp.           catalpa spp.              non-native      1
# Carya         laciniosa      shellbark hickory         native          1
# Cornus        spp.           dogwood spp.              non-native      1
# Prunus        cerasus        sour cherry               non-native      1
# Picea         engelmannii    Engelmann spruce          non-native      1
# Populus       alba           silver poplar             non-native      1
# Maclura       pomifera       Osage-orange              non-native      1
# Elaeagnus     angustifolia   Russian olive             non-native      1
# Morus         rubra          red mulberry              native          1
# Picea         rubens         red spruce                non-native      1
# Quercus       shumardii      Shumard oak               native          1
# Prunus        spp.           Prunus                    non-native      1
#               salicina       Japanese plum             non-native      1
#               x yedoensis    Yoshino flowering cherry  non-native      1
#               virginiana     chokecherry               native          1
# Thuja         plicata        western redcedar          non-native      1
# Tsuga         canadensis     eastern hemlock           non-native      1
# Ulmus         parvifolia     Chinese elm               non-native      1
# Name: count, dtype: int64

# %%
df = df_trees_chicago

df_labeled = df['GENUS'] + ' ' + df['SPECIES'] + ' (' + df['COMMON_NAME'] + ')'
df_labeled_counts = df_labeled.value_counts()

threshold = 22  # Determined by fiddling.
df_labeled_filtered = df_labeled_counts[df_labeled_counts >= threshold]
df_labeled_others = df_labeled_counts[df_labeled_counts < threshold].sum()

df_labeled_final = df_labeled_filtered.copy()
if df_labeled_others > 0:
    df_labeled_final['Other'] = df_labeled_others

ax = df_labeled_final.plot.pie(
    title='Species Represented in Chicago',
    autopct='%1.1f%%',
    pctdistance=0.85,
    startangle=-64,  # Determined by fiddling.
)
ax.set_ylabel('')
pass

# %%
ax = df_trees_chicago['NATIVITY'].map({'native': 'Native', 'non-native': 'Non-native'}).value_counts().plot.pie(
    title = 'Native vs. Non-native Trees Represented in Chicago',
    autopct='%1.1f%%',
    startangle=90,
)
ax.set_ylabel('')
pass

# %%
df = df_trees_chicago[df_trees_chicago['NATIVITY'] == 'native']

df_labeled = df['GENUS'] + ' ' + df['SPECIES'] + ' (' + df['COMMON_NAME'] + ')'
df_labeled_counts = df_labeled.value_counts()

threshold = 20  # Determined by fiddling.
df_labeled_filtered = df_labeled_counts[df_labeled_counts >= threshold]
df_labeled_others = df_labeled_counts[df_labeled_counts < threshold].sum()

df_labeled_final = df_labeled_filtered.copy()
if df_labeled_others > 0:
    df_labeled_final['Other'] = df_labeled_others

ax = df_labeled_final.plot.pie(
    title='Native Species Represented in Chicago',
    autopct='%1.1f%%',
    pctdistance=0.85,  # Determined by fiddling.
    startangle=-75,  # Determined by fiddling.
)
ax.set_ylabel('')
pass

# %%
df = df_trees_chicago[df_trees_chicago['NATIVITY'] != 'native']

df_labeled = df['GENUS'] + ' ' + df['SPECIES'] + ' (' + df['COMMON_NAME'] + ')'
df_labeled_counts = df_labeled.value_counts()

threshold = 10  # Determined by fiddling.
df_labeled_filtered = df_labeled_counts[df_labeled_counts >= threshold]
df_labeled_others = df_labeled_counts[df_labeled_counts < threshold].sum()

df_labeled_final = df_labeled_filtered.copy()
if df_labeled_others > 0:
    df_labeled_final['Other'] = df_labeled_others

ax = df_labeled_final.plot.pie(
    title='Native Species Represented in Chicago',
    autopct='%1.1f%%',
    pctdistance=0.85,  # Determined by fiddling.
    startangle=-90,  # Determined by fiddling.
)
ax.set_ylabel('')
pass

# %% [markdown]
# ### Where are the trees located?

# %%
def calculate_extents(df):
    return {
        "x_min": df['X'].min().item(),
        "x_max": df['X'].max().item(),
        "y_min": df['Y'].min().item(),
        "y_max": df['Y'].max().item(),
    }

def draw_heatmap(df, x_min=None, extents=None, n_bins=None, title=None, figsize=None):
    if extents is None:
        extents = calculate_extents(df)

    x_min = extents["x_min"]
    x_max = extents["x_max"]
    y_min = extents["y_min"]
    y_max = extents["y_max"]
    
    x_extent = x_max - x_min
    y_extent = y_max - y_min

    if n_bins is None:
        n_bins = 15
    bin_dim = x_extent / (n_bins + 1)  # feet per bin

    n_bins_x = n_bins
    n_bins_y = int(np.ceil(y_extent / bin_dim))

    dfbins = df.copy()
    dfbins['xbin'] = np.minimum(np.floor(((dfbins['X'] - x_min) / bin_dim)).astype(np.int64), n_bins_x - 1)
    dfbins['ybin'] = np.minimum(np.floor(((dfbins['Y'] - y_min) / bin_dim)).astype(np.int64), n_bins_y - 1)

    # y major indexing for this image
    heatmap_data = np.zeros((n_bins_y, n_bins_x), dtype=int)
    bin_counts = dfbins.groupby(['ybin', 'xbin']).size()
    for (ybin, xbin), count in bin_counts.items():
        if ybin >= 0 and ybin < n_bins_y and xbin >= 0 and xbin < n_bins_x:
            heatmap_data[ybin, xbin] = count

    if figsize is None:
        aspect_ratio = x_extent / y_extent
        figsize = (6, 6 / aspect_ratio)
    
    plt.figure(figsize=figsize)

    extent = [x_min, x_max, y_min, y_max]
    plt.imshow(heatmap_data, origin='lower', extent=extent, cmap='viridis')
    
    plt.colorbar(label='Number of Trees')
    if title is not None:
        plt.title(title)
    
    plt.show()

def draw_differential_map(df1, df2, x_min=None, extents=None, n_bins=None, title=None, figsize=None, label=None):
    if extents is None:
        extents = calculate_extents(pd.concat([df1, df2]))

    x_min = extents["x_min"]
    x_max = extents["x_max"]
    y_min = extents["y_min"]
    y_max = extents["y_max"]
    
    x_extent = x_max - x_min
    y_extent = y_max - y_min

    if n_bins is None:
        n_bins = 15
    bin_dim = x_extent / (n_bins + 1)  # feet per bin

    n_bins_x = n_bins
    n_bins_y = int(np.ceil(y_extent / (bin_dim + 1)))
    
    dfbins1 = df1.copy()
    dfbins1['xbin'] = np.floor(((dfbins1['X'] - x_min) / bin_dim)).astype(np.int64)
    dfbins1['ybin'] = np.floor(((dfbins1['Y'] - y_min) / bin_dim)).astype(np.int64)

    dfbins2 = df2.copy()
    dfbins2['xbin'] = np.floor(((dfbins2['X'] - x_min) / bin_dim)).astype(np.int64)
    dfbins2['ybin'] = np.floor(((dfbins2['Y'] - y_min) / bin_dim)).astype(np.int64)

    # y major indexing for this image
    biggest_count = 0
    heatmap_data = np.zeros((n_bins_y, n_bins_x), dtype=int)
    bin_counts = dfbins1.groupby(['ybin', 'xbin']).size()
    for (ybin, xbin), count in bin_counts.items():
        if ybin >= 0 and ybin < n_bins_y and xbin >= 0 and xbin < n_bins_x:
            heatmap_data[ybin, xbin] += count
            if count > biggest_count:
                biggest_count = count
    bin_counts = dfbins2.groupby(['ybin', 'xbin']).size()
    for (ybin, xbin), count in bin_counts.items():
        if ybin >= 0 and ybin < n_bins_y and xbin >= 0 and xbin < n_bins_x:
            heatmap_data[ybin, xbin] -= count
            if count > biggest_count:
                biggest_count = count

    if figsize is None:
        aspect_ratio = x_extent / y_extent
        figsize = (6, 6 / aspect_ratio)

    fig, ax = plt.subplots(figsize=figsize)

    extent = [x_min, x_max, y_min, y_max]
    im = ax.imshow(heatmap_data, origin='lower', extent=extent, cmap='seismic_r', vmin=-biggest_count, vmax=biggest_count)

    fig.colorbar(im, label='Number of Trees' if label is None else label)
    if title is not None:
        ax.set_title(title)
    
    plt.show()

extents_chicago = calculate_extents(df_trees_chicago)
def calculate_chicago_figsize(width):
    global extents_chicago
    aspect_ratio = (extents_chicago['x_max'] - extents_chicago['x_min']) / (extents_chicago['y_max'] - extents_chicago['y_min'])
    return (width, width / aspect_ratio)

# %%
df = df_trees_chicago
plt.figure(figsize=calculate_chicago_figsize(3))
plt.scatter(df['X'], df['Y'], s=.05)
plt.scatter([CHICAGO_X], [CHICAGO_Y], s=25, c='orange')
plt.scatter([GARY_X], [GARY_Y], s=25, c='orange')
plt.scatter([NAPERVILLE_X], [NAPERVILLE_Y], s=25, c='orange')
plt.scatter([WAUKEGEN_X], [WAUKEGEN_Y], s=25, c='orange')
plt.axis('equal')
plt.title('Location of Surveyed Trees in Chicago')

plt.show()

# %%
draw_heatmap(
    df_trees_chicago,
    extents=extents_chicago,
    title='Heatmap of the\nTrees of Chicago',
    n_bins=10,
)

# %%
draw_differential_map(
    df_trees_chicago[
        (df_trees_chicago['NATIVITY'] == 'native')
    ],
    df_trees_chicago[
        (df_trees_chicago['NATIVITY'] != 'native')
    ],
    extents=extents_chicago,
    title='Tree Nativity\nDifferential Map of Chicago',
    label='Number of Natives Trees Minus Non-native Trees',
    n_bins=10,
)

# %% [markdown]
# Some terms:
#
# * "Green" - Wood/bark that is cut from a live, healthy tree is called green (i.e. has a high moisture content).
# * Specific Gravity - Relative density, i.e. $\frac{\text{density A}}{\text{density B}}$.
#
# In the following charts, the plotted features have the following meanings:
#
# * `WOOD_SPGR_GREENVOL_DRYWT` - Specific gravity of green wood compared to dry weight.<br/>
#   $\frac{\text{oven dry weight}}{\text{green volume}\,\cdot\,\text{density of water}}$
# * `MC_PCT_GREEN_WOOD` - Moisture percent of green wood as percent of oven-dry weight.
# * `BARK_SPGR_GREENVOL_DRYWT` - Specific gravity of green bark compared to dry weight.<br/>
#   $\frac{\text{oven dry weight}}{\text{green volume}\,\cdot\,\text{density of water}}$
# * `MC_PCT_GREEN_BARK` - Moisture percent of green bark as percent of oven-dry weight.
# * `BARK_VOL_PCT` - Bark volume as percent of wood volume.
# * `CARBON_RATIO_LIVE` - Wood carbon fraction. Determined by elemental analysis of dry wood.

# %%
df = df_trees_chicago[['SPCD']].merge(
    df_ref_species,
    on=['SPCD'],
    how='left',
)
df[[
    'WOOD_SPGR_GREENVOL_DRYWT',
    'MC_PCT_GREEN_WOOD',
    'BARK_SPGR_GREENVOL_DRYWT',
    'MC_PCT_GREEN_BARK',
    'BARK_VOL_PCT',
    'CARBON_RATIO_LIVE',
]].hist(bins=10, figsize=(12,28), layout=(3, 2))
plt.show()

# %%
df = df_trees_chicago[['SPCD', 'NATIVITY']].merge(
    df_ref_species[['SPCD', 'GENUS', 'SPECIES', 'COMMON_NAME', 'BARK_VOL_PCT']],
    on=['SPCD'],
    how='left',
).groupby(['SPCD']).max()

print()

print("Least Bark:")
print()
display(df.sort_values(by=['BARK_VOL_PCT'])[:7])
print()

print("Most Bark:")
print()
display(df.sort_values(by=['BARK_VOL_PCT'], ascending=False)[:7])
print()
# Out:
# Least Bark:
#         NATIVITY        GENUS       SPECIES        COMMON_NAME  BARK_VOL_PCT
# SPCD
# 731       native     Platanus  occidentalis  American sycamore          8.00
# 8253  non-native     Platanus       hybrida   London planetree          8.00
# 316       native         Acer        rubrum          red maple          8.60
# 356   non-native  Amelanchier          spp.  serviceberry spp.          8.60
# 313       native         Acer       negundo           boxelder          8.60
# 317       native         Acer   saccharinum       silver maple          8.60
# 763       native       Prunus    virginiana        chokecherry          9.19
# Most Bark:
#      NATIVITY     GENUS        SPECIES         COMMON_NAME  BARK_VOL_PCT
# SPCD
# 742    native   Populus      deltoides  eastern cottonwood         22.00
# 830    native   Quercus      palustris             pin oak         22.00
# 221    native  Taxodium      distichum         baldcypress         20.00
# 833    native   Quercus          rubra    northern red oak         20.00
# 809    native   Quercus  ellipsoidalis    northern pin oak         19.12
# 834    native   Quercus      shumardii         Shumard oak         19.12
# 837    native   Quercus       velutina           black oak         18.50

# %%
df = df_trees_chicago[['SPCD', 'NATIVITY']].merge(
    df_ref_species[['SPCD', 'GENUS', 'SPECIES', 'COMMON_NAME', 'MC_PCT_GREEN_WOOD']],
    on=['SPCD'],
    how='left',
).groupby(['SPCD']).max()

print()

print("Wettest Woods:")
print()
display(df.sort_values(by=['MC_PCT_GREEN_WOOD'], ascending=False)[:7])
print()

print("Driest Woods:")
print()
display(df.sort_values(by=['MC_PCT_GREEN_WOOD'])[:7])
print()
# Out:
# Wettest Woods:
#         NATIVITY     GENUS        SPECIES         COMMON_NAME  \
# SPCD
# 331       native  Aesculus         glabra        Ohio buckeye
# 746       native   Populus    tremuloides       quaking aspen
# 922       native     Salix          nigra        black willow
# 929   non-native     Salix  x sepulcralis      weeping willow
# 920   non-native     Salix           spp.         willow spp.
# 12    non-native     Abies       balsamea          balsam fir
# 742       native   Populus      deltoides  eastern cottonwood
#
#       MC_PCT_GREEN_WOOD
# SPCD
# 331           143.00000
# 746           128.94286
# 922           127.02778
# 929           127.00000
# 920           127.00000
# 12            118.54545
# 742           116.56757
# Driest Woods:
#         NATIVITY        GENUS       SPECIES       COMMON_NAME  \
# SPCD
# 641   non-native      Maclura      pomifera      Osage-orange
# 68        native    Juniperus    virginiana  eastern redcedar
# 202   non-native  Pseudotsuga     menziesii       Douglas-fir
# 490   non-native       Cornus          spp.      dogwood spp.
# 242   non-native        Thuja       plicata  western redcedar
# 901   non-native      Robinia  pseudoacacia      black locust
# 541       native     Fraxinus     americana         white ash
#
#       MC_PCT_GREEN_WOOD
# SPCD
# 641            30.73684
# 68             34.75000
# 202            35.33333
# 490            39.50000
# 242            39.58065
# 901            40.83333
# 541            45.69091

# %%
df = df_trees_chicago[['SPCD', 'NATIVITY']].merge(
    df_ref_species[['SPCD', 'GENUS', 'SPECIES', 'COMMON_NAME', 'CARBON_RATIO_LIVE']],
    on=['SPCD'],
    how='left',
).groupby(['SPCD']).max()

print()

print("Lowest Carbon Ratio:")
print()
display(df.sort_values(by=['CARBON_RATIO_LIVE'])[:7])
print()

print("Highest Carbon Ratio:")
print()
display(df.sort_values(by=['CARBON_RATIO_LIVE'], ascending=False)[:7])
print()
# Out:
# Lowest Carbon Ratio:
#         NATIVITY      GENUS       SPECIES        COMMON_NAME  \
# SPCD
# 8813  non-native      Tilia       cordata  littleleaf linden
# 552       native  Gleditsia   triacanthos        honeylocust
# 471       native     Cercis    canadensis     eastern redbud
# 7631  non-native   Magnolia      stellata      star magnolia
# 974   non-native      Ulmus        pumila       Siberian elm
# 901   non-native    Robinia  pseudoacacia       black locust
# 931       native  Sassafras       albidum          sassafras
#
#       CARBON_RATIO_LIVE
# SPCD
# 8813              0.388
# 552               0.423
# 471               0.438
# 7631              0.441
# 974               0.443
# 901               0.446
# 931               0.450
# Highest Carbon Ratio:
#         NATIVITY        GENUS     SPECIES       COMMON_NAME  CARBON_RATIO_LIVE
# SPCD
# 125       native        Pinus    resinosa          red pine              0.533
# 68        native    Juniperus  virginiana  eastern redcedar              0.521
# 375       native       Betula  papyrifera       paper birch              0.519
# 202   non-native  Pseudotsuga   menziesii       Douglas-fir              0.516
# 94    non-native        Picea      glauca      white spruce              0.512
# 681   non-native        Morus        alba    white mulberry              0.511
# 15    non-native        Abies    concolor         white fir              0.510
